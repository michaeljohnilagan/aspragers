# %%
import numpy as np
import pandas as pd
from datasets import Dataset
from sentence_transformers import SentenceTransformer
import minsearch
import ollama
from datetime import datetime

# %% [markdown]
# # Load dataset

# %%
# load dataframe
df = pd.read_csv('../data/data-kb.csv', sep='\t', dtype=str) # they are all strings!
df
# Out:
#           pmid                              elocationid  \
# 0     40770710                                 pii: 769
# 1     40690320                                      NaN
# 2     40637642  doi: 10.5152/TurkArchPediatr.2025.25127
# 3     40597832                                 pii: 484
# 4     40527486               pii: S0021-7557(25)00099-3
# ...        ...                                      ...
# 2995   7866673                                      NaN
# 2996   7794327                                      NaN
# 2997  29871460                  doi: 10.1007/BF01978114
# 2998   7926319                                      NaN
# 2999   7841689                                      NaN
#
#                                                   title  \
# 0     The dynamic trajectory of autistic life and it...
# 1      [Quantitative analysis of autism online forums].
# 2     The Work of Grunya Efimovna Sukhareva in the F...
# 3     Autism spectrum disorders and childhood caries...
# 4     Psychometric characteristics of the Mini-TEA s...
# ...                                                 ...
# 2995   Linguistics, human communication and psychiatry.
# 2996  Prevalence of Asperger's syndrome in a secure ...
# 2997  A preliminary study of right hemisphere cognit...
# 2998  Developmental prosopagnosia in Asperger syndro...
# 2999      Is clumsiness a marker for Asperger syndrome?
#
#                                                 journal  year  \
# 0                                        BMC psychiatry  2025
# 1     Psychiatria Hungarica : A Magyar Pszichiatriai...  2025
# 2                        Turkish archives of pediatrics  2025
# 3                                        BMC pediatrics  2025
# 4                                   Jornal de pediatria  2025
# ...                                                 ...   ...
# 2995  The British journal of psychiatry : the journa...  1994
# 2996  The British journal of psychiatry : the journa...  1994
# 2997             European child & adolescent psychiatry  1994
# 2998         Developmental medicine and child neurology  1994
# 2999  Journal of intellectual disability research : ...  1994
#
#                                                  author  \
# 0     Leshata Winter Mokhwelepa, Gsakani Olivia Sumb...
# 1          Brigitta Kakuszi, Szilvia Hetesy, Pál Czobor
# 2                           Annio Posar, Paola Visconti
# 3     Qiufang Jin, Zexiu He, Dongfang Xu, Ruihua Lin...
# 4     Cassiano Mateus Forcelini, Regina Ampese, Hele...
# ...                                                 ...
# 2995                                 P Thomas, W Fraser
# 2996                                   P Scragg, A Shah
# 2997  Hadyn D Ellis, Diane M Ellis, William Fraser, ...
# 2998                                           I Kracke
# 2999       M Ghaziuddin, E Butler, L Tsai, N Ghaziuddin
#
#                                             affiliation  \
# 0     School of Medicine, Faculty of Health Science,...
# 1                                                   NaN
# 2     IRCCS Istituto delle Scienze Neurologiche di B...
# 3     Department of Otolaryngology, The Second Hospi...
# 4     Associação de Pais e Amigos dos Excepcionais (...
# ...                                                 ...
# 2995                                                NaN
# 2996                                                NaN
# 2997  Department of Psychological Medicine, Universi...
# 2998  Department of Psychology, Hollymoor Hospital, ...
# 2999                                                NaN
#
#                                                abstract
# 0     There is a noticeable knowledge vacuum on the ...
# 1     Social media platforms are becoming increasing...
# 2     Despite several articles that in recent years ...
# 3     This study aimed to investigate the causal rel...
# 4     Early diagnosis of autism spectrum disorder (A...
# ...                                                 ...
# 2995  Psycholinguistics and sociolinguistics have ex...
# 2996  The hypothesis that Asperger's syndrome (AS) m...
# 2997  Seven children and young adults with definite ...
# 2998  The case of a young man is presented who initi...
# 2999  Although Asperger syndrome (AS) has been inclu...
#
# [3000 rows x 8 columns]

# %% [markdown]
# # Embed data

# %% [markdown]
# ## Preprocessing

# %%
# count missing in each field
[df[column_name].isna().value_counts() for column_name in df.columns]
# Out:
# [pmid
#  False    3000
#  Name: count, dtype: int64,
#  elocationid
#  False    1758
#  True     1242
#  Name: count, dtype: int64,
#  title
#  False    2994
#  True        6
#  Name: count, dtype: int64,
#  journal
#  False    2995
#  True        5
#  Name: count, dtype: int64,
#  year
#  False    2972
#  True       28
#  Name: count, dtype: int64,
#  author
#  False    2939
#  True       61
#  Name: count, dtype: int64,
#  affiliation
#  True     1910
#  False    1090
#  Name: count, dtype: int64,
#  abstract
#  False    2644
#  True      356
#  Name: count, dtype: int64]

# %%
# fill in missing cells with empty string
for column_name in df.columns:
    df[column_name] = df[column_name].fillna('')

# %%
# combine text fields to be embedded
df_toembed = pd.DataFrame(df['journal']+' / '+df['title']+' / '+df['abstract'], columns=['text'])
df_toembed
# Out:
#                                                    text
# 0     BMC psychiatry / The dynamic trajectory of aut...
# 1     Psychiatria Hungarica : A Magyar Pszichiatriai...
# 2     Turkish archives of pediatrics / The Work of G...
# 3     BMC pediatrics / Autism spectrum disorders and...
# 4     Jornal de pediatria / Psychometric characteris...
# ...                                                 ...
# 2995  The British journal of psychiatry : the journa...
# 2996  The British journal of psychiatry : the journa...
# 2997  European child & adolescent psychiatry / A pre...
# 2998  Developmental medicine and child neurology / D...
# 2999  Journal of intellectual disability research : ...
#
# [3000 rows x 1 columns]

# %%
# how many words are the texts?
print(df_toembed['text'].apply(lambda x : len(x.split())).quantile([0.5, 0.75, 0.99, 1.0])) # percentiles
# Out:
# 0.50    136.00
# 0.75    185.00
# 0.99    387.02
# 1.00    983.00
# Name: text, dtype: float64

# %% [markdown]
# ## Work, in batches

# %%
def batch_embed(batch, model_handle_vectorizer='all-MiniLM-L6-v2'):
    vectorizer = SentenceTransformer(model_name_or_path=model_handle_vectorizer)
    return {'embedding' : vectorizer.encode(batch['text'])}

# %%
# by batch, embed text
print(datetime.now())
dataset_to_embed = Dataset.from_pandas(df_toembed)
list_of_docs_with_embeddings = dataset_to_embed.map(batch_embed, batched=True, batch_size=32)
print(datetime.now())
# Out:
# 2025-08-25 10:50:33.257416
# Map:   0%|          | 0/3000 [00:00<?, ? examples/s]
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 1s [Retry 1/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 2s [Retry 2/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 4s [Retry 3/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 8s [Retry 4/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 8s [Retry 5/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./config_sentence_transformers.json
# Retrying in 1s [Retry 1/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./config_sentence_transformers.json
# Retrying in 2s [Retry 2/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./config_sentence_transformers.json
# Retrying in 4s [Retry 3/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./config_sentence_transformers.json
# Retrying in 8s [Retry 4/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./config_sentence_transformers.json
# Retrying in 8s [Retry 5/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/README.md
# Retrying in 1s [Retry 1/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/README.md
# Retrying in 2s [Retry 2/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/README.md
# Retrying in 4s [Retry 3/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/README.md
# Retrying in 8s [Retry 4/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/README.md
# Retrying in 8s [Retry 5/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/README.md
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 1s [Retry 1/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 2s [Retry 2/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 4s [Retry 3/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 8s [Retry 4/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 8s [Retry 5/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 1s [Retry 1/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 2s [Retry 2/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 4s [Retry 3/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 8s [Retry 4/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 8s [Retry 5/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./config_sentence_transformers.json
# Retrying in 1s [Retry 1/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./config_sentence_transformers.json
# Retrying in 2s [Retry 2/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./config_sentence_transformers.json
# Retrying in 4s [Retry 3/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./config_sentence_transformers.json
# Retrying in 8s [Retry 4/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./config_sentence_transformers.json
# Retrying in 8s [Retry 5/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/1_Pooling/config.json
# Retrying in 1s [Retry 1/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/1_Pooling/config.json
# Retrying in 2s [Retry 2/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/1_Pooling/config.json
# Retrying in 4s [Retry 3/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/1_Pooling/config.json
# Retrying in 8s [Retry 4/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/1_Pooling/config.json
# Retrying in 8s [Retry 5/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/1_Pooling/config.json
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 1s [Retry 1/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 2s [Retry 2/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 4s [Retry 3/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 8s [Retry 4/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 8s [Retry 5/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./config_sentence_transformers.json
# Retrying in 1s [Retry 1/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./config_sentence_transformers.json
# Retrying in 2s [Retry 2/5].
# 2025-08-25 10:56:58.249359

# %%
# numpy format embeddings
embeddings = np.array([doc['embedding'] for doc in list_of_docs_with_embeddings])
embeddings
# Out:
# array([[-0.02014046, -0.01249517, -0.03239842, ...,  0.05398439,
#          0.02627808,  0.05590913],
#        [-0.04988108, -0.05125703, -0.04357366, ...,  0.0861038 ,
#         -0.00495032,  0.04734036],
#        [-0.06211504, -0.01873365, -0.11244083, ...,  0.02616481,
#         -0.02174573,  0.09641958],
#        ...,
#        [-0.00082186,  0.01687531, -0.08099026, ...,  0.1024764 ,
#         -0.05948333,  0.00125555],
#        [ 0.02463584,  0.04507218, -0.08503982, ...,  0.08198918,
#          0.03921755,  0.04240407],
#        [ 0.01920908, -0.09527313, -0.01468155, ...,  0.0642341 ,
#         -0.01229316,  0.0252928 ]], shape=(3000, 384))

# %% [markdown]
# # CSV file

# %%
# write CSV file
np.savetxt('../data/embed-kb.csv', embeddings, delimiter=',')

# %%
print(datetime.now())
# Out:
# 2025-08-25 10:56:59.108726
