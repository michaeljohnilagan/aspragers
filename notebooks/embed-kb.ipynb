# %%
import numpy as np
import pandas as pd
from datasets import Dataset
from datetime import datetime

# %%
import sys
sys.path.append('../scripts')
import vectors

# %% [markdown]
# # Load dataset

# %%
# load dataframe
df = pd.read_csv('../data/data-kb.csv', sep='\t', dtype=str) # they are all strings!
df
# Out:
#           pmid                            elocationid  \
# 0     40939192      doi: 10.1097/WNF.0000000000000653
# 1     40938792     doi: 10.1080/09638237.2025.2558503
# 2     40938690      doi: 10.1097/HRP.0000000000000437
# 3     40938348         doi: 10.1177/2161783X251378518
# 4     40938167     doi: 10.1080/00207578.2024.2394076
# ...        ...                                    ...
# 2995  40246257  doi: 10.1016/j.neuroimage.2025.121217
# 2996  40245451      doi: 10.1016/j.infbeh.2025.102057
# 2997  40245419      doi: 10.1097/AOG.0000000000005896
# 2998  40245385                            pii: e63378
# 2999  40244830             doi: 10.1089/cap.2025.0021
#
#                                                   title  \
# 0     Psilocybin Use in the Autism Spectrum Disorder...
# 1     Understanding the countermovement to online pr...
# 2     Comorbid Autism, Anxiety, and ADHD in a Preado...
# 3     MazeOut Adaptive Serious Game: Evaluation of P...
# 4     A reading of stereotypy in autism through the ...
# ...                                                 ...
# 2995  Interbrain synchrony attenuation during a peer...
# 2996  Emerging sensitivity to talking mouth in infan...
# 2997  Acetaminophen in Pregnancy and Attention-Defic...
# 2998  Evaluating a Web-Based Application to Facilita...
# 2999                                                NaN
#
#                                                 journal  year  \
# 0                            Clinical neuropharmacology  2025
# 1          Journal of mental health (Abingdon, England)  2025
# 2                          Harvard review of psychiatry  2025
# 3                              Games for health journal  2025
# 4          The International journal of psycho-analysis  2025
# ...                                                 ...   ...
# 2995                                         NeuroImage  2025
# 2996                      Infant behavior & development  2025
# 2997                          Obstetrics and gynecology  2025
# 2998                            JMIR research protocols  2025
# 2999  Journal of child and adolescent psychopharmaco...  2025
#
#                                                  author  \
# 0     Jaime Moreno-Chaparro, Gabriela Castañeda-Mill...
# 1            Vaughan Bell, Rhiannon White, Lucy Foulkes
# 2     Elizabeth Steuber, Jason Fogler, Oscar Bukstei...
# 3     Alexandre Kira, Rodrigo G Pontes, Augusto K Pe...
# 4                                         Leandro Jofré
# ...                                                 ...
# 2995  I-Chun Chen, Hao-Che Hsu, Chia-Ling Chen, Meng...
# 2996  Masahiro Hata, Mingdi Xu, Yoko Hakuno, Eriko Y...
# 2997                                    Daniel W Cramer
# 2998  Eric Meyer, Hélène Sauzéon, Isabeau Saint-Supe...
# 2999                            Sally Chu, H Yavuz Ince
#
#                                             affiliation  \
# 0     Hospital Universitario Nacional de Colombia, B...
# 1     Department of Experimental Psychology, Univers...
# 2     From Harvard Medical School (Drs. Steuber, Fog...
# 3     School of Arts, Sciences and Humanities, Unive...
# 4     Department of Clinical Psychology, Aix Marseil...
# ...                                                 ...
# 2995  Department of Physical Medicine and Rehabilita...
# 2996  Center for Design of Future Symbiosis, Keio Un...
# 2997  Department of Obstetrics, Gynecology and Repro...
# 2998  Flowers team-project, Inria Research Center of...
# 2999  Department of Psychiatry, Division of Child an...
#
#                                                abstract
# 0     Due to the boom in the use of certain psychede...
# 1     The self-presentation of psychiatric disorders...
# 2     Autism spectrum disorder (ASD) is often comorb...
# 3                                                   NaN
# 4     Stereotypies currently occupy an important pla...
# ...                                                 ...
# 2995  Young children with autism spectrum disorder (...
# 2996  The talker's mouth provides significant multim...
# 2997                                                NaN
# 2998  An individual education plan (IEP) is a key el...
# 2999                                                NaN
#
# [3000 rows x 8 columns]

# %% [markdown]
# # Embed data

# %% [markdown]
# ## Preprocessing

# %%
# make all missing values empty strings
df = vectors.preprocess_for_vectorization(df).copy()

# %%
# combine text fields to be embedded
df_toembed = pd.DataFrame(df['journal']+' / '+df['title']+' / '+df['abstract'], columns=['text'])
df_toembed
# Out:
#                                                    text
# 0     Clinical neuropharmacology / Psilocybin Use in...
# 1     Journal of mental health (Abingdon, England) /...
# 2     Harvard review of psychiatry / Comorbid Autism...
# 3     Games for health journal / MazeOut Adaptive Se...
# 4     The International journal of psycho-analysis /...
# ...                                                 ...
# 2995  NeuroImage / Interbrain synchrony attenuation ...
# 2996  Infant behavior & development / Emerging sensi...
# 2997  Obstetrics and gynecology / Acetaminophen in P...
# 2998  JMIR research protocols / Evaluating a Web-Bas...
# 2999  Journal of child and adolescent psychopharmaco...
#
# [3000 rows x 1 columns]

# %%
# how many words are the texts?
print(df_toembed['text'].apply(lambda x : \
len(x.split())).quantile([0.5, 0.75, 0.99, 1.0])) # percentiles
# Out:
# 0.50    120.00
# 0.75    221.00
# 0.99    427.02
# 1.00    554.00
# Name: text, dtype: float64

# %% [markdown]
# ## Work, in batches

# %%
# vectorizer handle
print(vectors.model_handle)
# Out:
# multi-qa-MiniLM-L6-cos-v1

# %%
def batch_embed(batch):
    vectorizer = vectors.model # use locally saved model
    return {'embedding' : vectorizer.encode(batch['text'])}

# %%
# by batch, embed text
print(datetime.now())
dataset_to_embed = Dataset.from_pandas(df_toembed)
list_of_docs_with_embeddings = dataset_to_embed.map(batch_embed, batched=True, batch_size=32)
print(datetime.now())
# Out:
# 2025-09-13 01:40:07.918161
# Map:   0%|          | 0/3000 [00:00<?, ? examples/s]
# 2025-09-13 01:43:15.163391

# %%
# numpy format embeddings
embeddings = np.array([doc['embedding'] for doc in list_of_docs_with_embeddings])
embeddings
# Out:
# array([[-0.05128488, -0.07618695, -0.04385687, ...,  0.12556736,
#         -0.03304618,  0.02123052],
#        [-0.0085128 , -0.1184947 , -0.07520135, ...,  0.06691602,
#         -0.02193654,  0.06407122],
#        [ 0.00201873, -0.01339388, -0.03751471, ...,  0.08187042,
#         -0.01049393,  0.08249757],
#        ...,
#        [-0.01568839, -0.05108237, -0.03650151, ...,  0.03155734,
#          0.0297182 ,  0.08517637],
#        [ 0.001147  ,  0.03333908, -0.0684872 , ..., -0.01114524,
#          0.06441785,  0.0063974 ],
#        [-0.0016648 , -0.0109417 , -0.09669736, ...,  0.05127326,
#          0.12472019, -0.05116935]], shape=(3000, 384))

# %% [markdown]
# # CSV file

# %%
# write CSV file
np.savetxt('../data/embed-kb.csv', embeddings, delimiter=',')

# %%
print(datetime.now())
# Out:
# 2025-09-13 01:43:16.092887
