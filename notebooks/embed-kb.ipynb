# %%
import numpy as np
import pandas as pd
from datasets import Dataset
from datetime import datetime

# %%
import vectors

# %% [markdown]
# # Load dataset

# %%
# load dataframe
df = pd.read_csv('../data/data-kb.csv', sep='\t', dtype=str) # they are all strings!
df
# Out:
#           pmid                            elocationid  \
# 0     40935315   doi: 10.1016/j.expneurol.2025.115457
# 1     40935250         doi: 10.1016/j.jad.2025.120270
# 2     40935239             pii: S0306-4522(25)00924-8
# 3     40934839     doi: 10.1016/j.seizure.2025.08.030
# 4     40934838     doi: 10.1016/j.seizure.2025.09.004
# ...        ...                                    ...
# 2995  40242676                            pii: e80721
# 2996  40242361                           pii: e102012
# 2997  40242083                            pii: 100765
# 2998  40241535                             pii: 24121
# 2999  40241368  doi: 10.7499/j.issn.1008-8830.2411142
#
#                                                   title  \
# 0     Longitudinal analysis of age-dependent phenoty...
# 1     Adverse childhood experiences and cardiometabo...
# 2     Endocrine circuitry in autism spectrum disorde...
# 3     Tough to treat: What we know about managing PC...
# 4     Characterizing CHD2-associated epilepsy: A mul...
# ...                                                 ...
# 2995  Current Clinical Practices for Gaming Disorder...
# 2996  Evaluating the feasibility, safety and efficac...
# 2997  Neuropsychiatric disorders in Chinese pediatri...
# 2998  [The transition from child to adult health car...
# 2999  [Advances in research on gender differences in...
#
#                                                 journal  year  \
# 0                                Experimental neurology  2025
# 1                        Journal of affective disorders  2025
# 2                                          Neuroscience  2025
# 3                                               Seizure  2025
# 4                                               Seizure  2025
# ...                                                 ...   ...
# 2995                                             Cureus  2025
# 2996                                 General psychiatry  2025
# 2997                        Epilepsy & behavior reports  2025
# 2998                                     Lakartidningen  2025
# 2999  Zhongguo dang dai er ke za zhi = Chinese journ...  2025
#
#                                                  author  \
# 0     Aiswaria Lekshmi Kannan, Abhisarika Patnaik, A...
# 1     Alyna Turner, Maya Kuperberg, Hugh McGovern, A...
# 2     Maria Angelopoulou, Panayiotis Siaperas, Saran...
# 3     Aleksandra Tobiasz, Monika Hager, Julia Dębows...
# 4     Anabel G Puri, Sean Woods, John M Schreiber, C...
# ...                                                 ...
# 2995  Masaru Tateno, Yukie Tateno, Tomohiro Shirasak...
# 2996  Hangyu Tan, Mingyu Xu, Tai Ren, Lin Deng, Ling...
# 2997  Jie Fu, Qinrui Li, Genfu Zhang, Zhixian Yang, ...
# 2998  Sven Bölte, Tatja Hirvikoski, Ulf Jonsson, Joh...
# 2999  Tong-Tong Jiang, Xiu-Qiong Li, Ting-Ting Zhao,...
#
#                                             affiliation  \
# 0     Neuroscience Division, IRCCS San Raffaele Scie...
# 1     Deakin University, School of Medicine, IMPACT,...
# 2     Department of Pediatric Endocrinology, Univers...
# 3     Students' Scientific Society, Department of Pe...
# 4     Department of Pediatrics, Division of Pediatri...
# ...                                                 ...
# 2995  Pediatrics, Furuta Pediatric Clinic, Sapporo, ...
# 2996  Ministry of Education - Shanghai Key Laborator...
# 2997  Department of Pediatrics, Peking University Pe...
# 2998                                                NaN
# 2999                                                NaN
#
#                                                abstract
# 0     Mutations in cyclin-dependent kinase-like 5 (C...
# 1     Bipolar disorder is associated with increased ...
# 2     The increasing global prevalence of Autism Spe...
# 3     PCDH19-related epilepsy is a rare, X-linked de...
# 4     CHD2 variants have been implicated in a spectr...
# ...                                                 ...
# 2995  Gaming is a popular leisure activity among chi...
# 2996                                                NaN
# 2997  Tuberous sclerosis complex (TSC) is an autosom...
# 2998  The transition from child to adult health care...
# 2999  Autism spectrum disorder (ASD) is a neurodevel...
#
# [3000 rows x 8 columns]

# %% [markdown]
# # Embed data

# %% [markdown]
# ## Preprocessing

# %%
# make all missing values empty strings
df = vectors.preprocess_for_vectorization(df).copy()

# %%
# combine text fields to be embedded
df_toembed = pd.DataFrame(df['journal']+' / '+df['title']+' / '+df['abstract'], columns=['text'])
df_toembed
# Out:
#                                                    text
# 0     Experimental neurology / Longitudinal analysis...
# 1     Journal of affective disorders / Adverse child...
# 2     Neuroscience / Endocrine circuitry in autism s...
# 3     Seizure / Tough to treat: What we know about m...
# 4     Seizure / Characterizing CHD2-associated epile...
# ...                                                 ...
# 2995  Cureus / Current Clinical Practices for Gaming...
# 2996  General psychiatry / Evaluating the feasibilit...
# 2997  Epilepsy & behavior reports / Neuropsychiatric...
# 2998  Lakartidningen / [The transition from child to...
# 2999  Zhongguo dang dai er ke za zhi = Chinese journ...
#
# [3000 rows x 1 columns]

# %%
# how many words are the texts?
print(df_toembed['text'].apply(lambda x : \
len(x.split())).quantile([0.5, 0.75, 0.99, 1.0])) # percentiles
# Out:
# 0.50    121.00
# 0.75    222.00
# 0.99    427.02
# 1.00    554.00
# Name: text, dtype: float64

# %% [markdown]
# ## Work, in batches

# %%
# vectorizer handle
print(vectors.model_handle)
# Out:
# multi-qa-MiniLM-L6-cos-v1

# %%
def batch_embed(batch):
    vectorizer = vectors.model # use locally saved model
    return {'embedding' : vectorizer.encode(batch['text'])}

# %%
# by batch, embed text
print(datetime.now())
dataset_to_embed = Dataset.from_pandas(df_toembed)
list_of_docs_with_embeddings = dataset_to_embed.map(batch_embed, batched=True, batch_size=32)
print(datetime.now())
# Out:
# 2025-09-12 01:18:31.927453
# Map:   0%|          | 0/3000 [00:00<?, ? examples/s]
# 2025-09-12 01:21:50.513556

# %%
# numpy format embeddings
embeddings = np.array([doc['embedding'] for doc in list_of_docs_with_embeddings])
embeddings
# Out:
# array([[-0.01331419,  0.03100735,  0.04415156, ...,  0.00295215,
#          0.06678268, -0.03614511],
#        [ 0.01364253, -0.00099124, -0.042556  , ...,  0.03705724,
#         -0.04389741,  0.04818445],
#        [-0.01475928, -0.06944643, -0.02060538, ...,  0.08121259,
#          0.00358058,  0.06985687],
#        ...,
#        [-0.00197059, -0.02888306,  0.02024219, ...,  0.04638129,
#          0.0319542 ,  0.04328557],
#        [-0.02215269,  0.03331943, -0.05798261, ...,  0.04557109,
#          0.06766746,  0.07463718],
#        [-0.02466955,  0.01206873, -0.07816666, ...,  0.07700495,
#          0.00649813,  0.05432483]], shape=(3000, 384))

# %% [markdown]
# # CSV file

# %%
# write CSV file
np.savetxt('../data/embed-kb.csv', embeddings, delimiter=',')

# %%
print(datetime.now())
# Out:
# 2025-09-12 01:21:51.489017
