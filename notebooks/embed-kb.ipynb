# %%
import numpy as np
import pandas as pd
from datasets import Dataset
from datetime import datetime

# %%
import sys
sys.path.append('../scripts')
import vectors

# %% [markdown]
# # Load dataset

# %%
# load dataframe
df = pd.read_csv('../data/data-kb.csv', sep='\t', dtype=str) # they are all strings!
df
# Out:
#           pmid                         elocationid  \
# 0     40938348      doi: 10.1177/2161783X251378518
# 1     40938167  doi: 10.1080/00207578.2024.2394076
# 2     40938164  doi: 10.1080/00207578.2025.2518487
# 3     40938123           doi: 10.1128/mra.00701-25
# 4     40937558              doi: 10.1002/aur.70118
# ...        ...                                 ...
# 2995  40245385                         pii: e63378
# 2996  40244830          doi: 10.1089/cap.2025.0021
# 2997  40244560     doi: 10.1007/s12035-025-04929-y
# 2998  40244507     doi: 10.1007/s10803-025-06818-8
# 2999  40244506     doi: 10.1007/s10803-025-06822-y
#
#                                                   title  \
# 0     MazeOut Adaptive Serious Game: Evaluation of P...
# 1     A reading of stereotypy in autism through the ...
# 2               On man who lives once every two times:
# 3                                   Genome sequence of
# 4     Differences in the Social Experiences of Autis...
# ...                                                 ...
# 2995  Evaluating a Web-Based Application to Facilita...
# 2996                                                NaN
# 2997  Transcriptomics of Various Diseases Reveals th...
# 2998  The Relationship Between Avoidant/Restrictive ...
# 2999  Autism Spectrum Disorder Phenotypes Based on S...
#
#                                                 journal  year  \
# 0                              Games for health journal  2025
# 1          The International journal of psycho-analysis  2025
# 2          The International journal of psycho-analysis  2025
# 3                   Microbiology resource announcements  2025
# 4     Autism research : official journal of the Inte...  2025
# ...                                                 ...   ...
# 2995                            JMIR research protocols  2025
# 2996  Journal of child and adolescent psychopharmaco...  2025
# 2997                             Molecular neurobiology  2025
# 2998      Journal of autism and developmental disorders  2025
# 2999      Journal of autism and developmental disorders  2025
#
#                                                  author  \
# 0     Alexandre Kira, Rodrigo G Pontes, Augusto K Pe...
# 1                                         Leandro Jofré
# 2                                          Jan Borowicz
# 3     Zhongsheng Zhu, Jiaojie Guan, Xiuxiu Xie, Chuq...
# 4           Ellie Roberts, William Mandy, Eirini Flouri
# ...                                                 ...
# 2995  Eric Meyer, Hélène Sauzéon, Isabeau Saint-Supe...
# 2996                            Sally Chu, H Yavuz Ince
# 2997  Yuxiang Zhang, Junjia Pan, Deqin Zeng, Yifan W...
# 2998  Borte Gurbuz Ozgur, Buket Canlan Ozaydin, Rabi...
# 2999  Kristina P Lenker, Yanling Li, Julio Fernandez...
#
#                                             affiliation  \
# 0     Institute of Mathematics and Statistics, Unive...
# 1     Department of Clinical Psychology, Aix Marseil...
# 2     Polish Psychoanalytical Society, Warszawa, Pol...
# 3     State Key Laboratory of Quantitative Synthetic...
# 4     Research Department of Clinical, Educational, ...
# ...                                                 ...
# 2995  GRHAPES (Research group on disability, accessi...
# 2996  Department of Psychiatry, Division of Child an...
# 2997  Key Laboratory of Brain, Cognition and Educati...
# 2998  Department of Child and Adolescent Psychiatry,...
# 2999  Sleep Research & Treatment Center, Penn State ...
#
#                                                abstract
# 0                                                   NaN
# 1     Stereotypies currently occupy an important pla...
# 2     The essay delineates a psychic phenomenon of i...
# 3         Here, we report the draft genome sequence of
# 4     Adolescence is a time of complex social and em...
# ...                                                 ...
# 2995  An individual education plan (IEP) is a key el...
# 2996                                                NaN
# 2997  Retinal ganglion cells (RGCs) are the only neu...
# 2998  The aim is to examine the relationship between...
# 2999  Previous studies have used cluster analysis to...
#
# [3000 rows x 8 columns]

# %% [markdown]
# # Embed data

# %% [markdown]
# ## Preprocessing

# %%
# make all missing values empty strings
df = vectors.preprocess_for_vectorization(df).copy()

# %%
# combine text fields to be embedded
df_toembed = pd.DataFrame(df['journal']+' / '+df['title']+' / '+df['abstract'], columns=['text'])
df_toembed
# Out:
#                                                    text
# 0     Games for health journal / MazeOut Adaptive Se...
# 1     The International journal of psycho-analysis /...
# 2     The International journal of psycho-analysis /...
# 3     Microbiology resource announcements / Genome s...
# 4     Autism research : official journal of the Inte...
# ...                                                 ...
# 2995  JMIR research protocols / Evaluating a Web-Bas...
# 2996  Journal of child and adolescent psychopharmaco...
# 2997  Molecular neurobiology / Transcriptomics of Va...
# 2998  Journal of autism and developmental disorders ...
# 2999  Journal of autism and developmental disorders ...
#
# [3000 rows x 1 columns]

# %%
# how many words are the texts?
print(df_toembed['text'].apply(lambda x : \
len(x.split())).quantile([0.5, 0.75, 0.99, 1.0])) # percentiles
# Out:
# 0.50    121.00
# 0.75    222.00
# 0.99    427.02
# 1.00    554.00
# Name: text, dtype: float64

# %% [markdown]
# ## Work, in batches

# %%
# vectorizer handle
print(vectors.model_handle)
# Out:
# multi-qa-MiniLM-L6-cos-v1

# %%
def batch_embed(batch):
    vectorizer = vectors.model # use locally saved model
    return {'embedding' : vectorizer.encode(batch['text'])}

# %%
# by batch, embed text
print(datetime.now())
dataset_to_embed = Dataset.from_pandas(df_toembed)
list_of_docs_with_embeddings = dataset_to_embed.map(batch_embed, batched=True, batch_size=32)
print(datetime.now())
# Out:
# 2025-09-12 22:06:23.070247
# Map:   0%|          | 0/3000 [00:00<?, ? examples/s]
# 2025-09-12 22:09:31.690999

# %%
# numpy format embeddings
embeddings = np.array([doc['embedding'] for doc in list_of_docs_with_embeddings])
embeddings
# Out:
# array([[-0.00536768, -0.00378355, -0.0310444 , ...,  0.07400885,
#         -0.0558759 ,  0.03560281],
#        [ 0.01141852, -0.0362408 , -0.06526048, ...,  0.10050427,
#          0.08973855, -0.00520128],
#        [-0.00448757, -0.02038934, -0.12113998, ...,  0.04732656,
#          0.02522353, -0.06889893],
#        ...,
#        [-0.08706112, -0.08085343,  0.00855536, ...,  0.00785196,
#          0.0874615 ,  0.00609161],
#        [ 0.00642245, -0.0515648 ,  0.01610286, ...,  0.03731215,
#         -0.03256838,  0.06655011],
#        [ 0.02142863, -0.02856287, -0.02955351, ...,  0.09405521,
#         -0.00435511,  0.05343657]], shape=(3000, 384))

# %% [markdown]
# # CSV file

# %%
# write CSV file
np.savetxt('../data/embed-kb.csv', embeddings, delimiter=',')

# %%
print(datetime.now())
# Out:
# 2025-09-12 22:09:32.628328
